# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.gca()

Mn = np.array([0,0.9974,3.32831,6.6942,10.3577])
Mp = np.array([0,0.995,3.265,6.695,10.36])



plt.title("Linearità",fontweight="bold")
plt.xlabel("Mnominale(g)",fontweight="bold")
plt.ylabel("Mpesata(g)",fontweight="bold")

plt.grid(color='lightgray',linestyle="--",zorder=0)

fit,cov = np.polyfit(Mn,Mp,1,cov="True")
merr,qerr = np.sqrt(np.diag(cov))
m,q = fit

x = np.linspace(0,12,1000)

print("m")
print(m)
print("merr")
print(merr)
print("q")
print(q)
print("qerr")
print(qerr)



y = q + m*x 

y_erroreMin = (q-qerr) + (m-merr)*x

y_erroreMax = (q+qerr) + (m+merr)*x

plt.scatter(Mn,Mp)
plt.fill_between(x,y_erroreMin,y_erroreMax, color="lightgreen",zorder=1)
plt.show()

Mf = q+m*Mn

Ri = Mf-Mp

fig = plt.figure()
ax = fig.gca()
plt.title("Grafico dei residui Masse",fontweight="bold")
plt.xlabel("Mn (g)",fontweight="bold")
plt.ylabel("Ri (g)",fontweight="bold")
plt.plot(np.linspace(0,12,1000),np.zeros(1000))
plt.scatter(Mn,Ri, s=30, color='blue',zorder=3)

plt.show()




MaxResidui = np.abs(Ri)



print("Errore = MaxResidui/sqrt(3)")
print(np.max(MaxResidui)/3**(1/3))


sigma_post_fit = (np.sum((Mf-Mp)**2)/(len(Mf)-2))**(1/2)
print("sigma_post_fit")
print(sigma_post_fit)

#TOGLIENDO IL PUNTO CON IL FLUIDO

Mn = np.array([0,0.9974,6.6942,10.3577])
Mp = np.array([0,0.995,6.695,10.36])

fit,cov = np.polyfit(Mn,Mp,1,cov="True")
merr,qerr = np.sqrt(np.diag(cov))
m,q = fit

x = np.linspace(0,12,1000)

print("m")
print(m)
print("merr")
print(merr)
print("q")
print(q)
print("qerr")
print(qerr)



y = q + m*x 

y_erroreMin = (q-qerr) + (m-merr)*x

y_erroreMax = (q+qerr) + (m+merr)*x

plt.scatter(Mn,Mp)
plt.fill_between(x,y_erroreMin,y_erroreMax, color="lightgreen",zorder=1)
plt.show()

Mf = q+m*Mn

Ri = Mf-Mp

fig = plt.figure()
ax = fig.gca()
plt.title("Grafico dei residui Masse",fontweight="bold")
plt.xlabel("Mn (g)",fontweight="bold")
plt.ylabel("Ri (g)",fontweight="bold")
plt.plot(np.linspace(0,12,1000),np.zeros(1000))
plt.scatter(Mn,Ri, s=30, color='blue',zorder=3)

plt.show()




MaxResidui = np.abs(Ri)



print("Errore = MaxResidui/sqrt(3)")
print(np.max(MaxResidui)/3**(1/3))


sigma_post_fit = (np.sum((Mf-Mp)**2)/(len(Mf)-2))**(1/2)
print("sigma_post_fit")
print(sigma_post_fit)
# Out:
# m
# 1.0011510749449994
# merr
# 0.0037922741200706335
# q
# -0.01744344625099512
# qerr
# 0.021729877444433818
# Errore = MaxResidui/sqrt(3)
# 0.034458452283402746
# sigma_post_fit
# 0.032349293096061896
# m
# 1.000329761476181
# merr
# 0.00016234791957692112
# q
# -0.00131299095300457
# qerr
# 0.0010043586493139404
# Errore = MaxResidui/sqrt(3)
# 0.000981739341434879
# sigma_post_fit
# 0.0013741652125966774
